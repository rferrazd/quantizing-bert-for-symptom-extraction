# %% [markdown]
# # Prepare HF Dataset and Upload it to the HF Hub

# %% [markdown]
# # V02 (first we will create an exact copy of V01 to test the differences between training the just the classifier head versus the entire model)

# %% [markdown]
# ## BioBERT

# %%
from datasets import load_dataset

data_files = {
"train": "../v01/data/biobert_splits/train.jsonl",
"validation": "../v01/data/biobert_splits/val.jsonl",
"test" : "../v01/data/biobert_splits/test.jsonl"
}

dataset = load_dataset("json", data_files=data_files)
print(dataset)
# Out:
# Generating train split: 14288 examples [00:00, 314291.79 examples/s]
# Generating validation split: 1786 examples [00:00, 320197.77 examples/s]
# Generating test split: 1786 examples [00:00, 575259.33 examples/s]
# DatasetDict({
#     train: Dataset({
#         features: ['text', 'word_tokens', 'word_labels', 'tokens', 'input_ids', 'token_labels', 'token_label_ids'],
#         num_rows: 14288
#     })
#     validation: Dataset({
#         features: ['text', 'word_tokens', 'word_labels', 'tokens', 'input_ids', 'token_labels', 'token_label_ids'],
#         num_rows: 1786
#     })
#     test: Dataset({
#         features: ['text', 'word_tokens', 'word_labels', 'tokens', 'input_ids', 'token_labels', 'token_label_ids'],
#         num_rows: 1786
#     })
# })

# %%
dataset.push_to_hub("Rogarcia18/symptoms_ner_v02_biobert", private=False)
# Out:
# Creating parquet from Arrow format: 100%|██████████| 1/1 [00:00<00:00, 25.74ba/s]
# Processing Files (1 / 1): 100%|██████████|  788kB /  788kB,  788kB/s
# New Data Upload: |          |  0.00B /  0.00B,  0.00B/s
# ...
# Creating parquet from Arrow format: 100%|██████████| 1/1 [00:00<00:00, 183.99ba/s]
# Processing Files (1 / 1): 100%|██████████|  119kB /  119kB,  298kB/s
# New Data Upload: |          |  0.00B /  0.00B,  0.00B/s
# ...
# Creating parquet from Arrow format: 100%|██████████| 1/1 [00:00<00:00, 174.55ba/s]
# Processing Files (1 / 1): 100%|██████████|  119kB /  119kB,  0.00B/s
# New Data Upload: |          |  0.00B /  0.00B,  0.00B/s
# Uploading the dataset shards: 100%|██████████| 1/1 [00:01<00:00,  1.32s/ shards]
# ...

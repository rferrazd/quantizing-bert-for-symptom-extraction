# %%
from torch.utils.data import Dataset, DataLoader

# %%
class CustomDataset(Dataset):
    def __init__(self,text,tokens,labels,max_len):
        self.text=text
        self.tokens=tokens
        self.labels=labels
        self.max_len=max_len

    #...

    def __get__

    def __getitem__
